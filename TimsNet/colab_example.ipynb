# %%
# !git clone 'https://github.com/leekyuyoung20230313/1.team.git'
# Out:
# Cloning into '1.team'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 42 (delta 7), reused 20 (delta 2), pack-reused 0
# Receiving objects: 100% (42/42), 56.07 KiB | 1.70 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# %cd '/content/1.team/TimsNet'
# Out:
# /content/1.team/TimsNet

# %%
# !python 'times_traintest.py' --train_path '/content/1.team/TimsNet/sample_data/s_train1.csv' '/content/1.team/TimsNet/sample_data/s_train2.csv' --val_path '/content/1.team/TimsNet/sample_data/s_val1.csv' '/content/1.team/TimsNet/sample_data/s_val2.csv' --test_path '/content/1.team/TimsNet/sample_data/s_test1.csv' '/content/1.team/TimsNet/sample_data/s_test2.csv' --lr 0.001 --epochs 1 --batch_sizes 2
# Out:
# Epoch 1/1: 100% 333/333 [00:14<00:00, 22.37it/s]
# Epoch 1/1, Training Loss: 48575.332306916294, Validation Loss: 40563.69999882695
# Epoch 1/1: 100% 333/333 [00:07<00:00, 44.59it/s]
# Epoch 1/1, Training Loss: 36087.029906859985, Validation Loss: 42101.06220673799
# Testing Loss: 49818.853515625
# Testing Loss: 72355.126953125

# %%
import pandas as pd
result = pd.read_csv('/content/1.team/TimsNet/results.csv')
result
# Out:
#          Pred_0    Pred_1     Pred_2      Pred_3  True_0  True_1  True_2  \
# 0     28.874002  2.996539  40.921932  2055.54300    29.1     2.4    48.0
# 1     28.894157  3.067444  39.979510  1945.62680    29.2     1.7    46.0
# 2     28.349714  3.052097  41.347550  1729.46290    29.4     1.1    45.0
# 3     27.077140  2.907276  45.709120  1447.08350    28.4     2.3    46.0
# 4     25.608887  2.681819  51.393036  1206.64320    27.3     1.4    50.0
# ...         ...       ...        ...         ...     ...     ...     ...
# 1339  27.074738  2.489737  83.379750   751.29510    25.3     0.4    80.0
# 1340  26.824900  2.450778  84.508540   732.41080    25.4     0.3    81.0
# 1341  26.630627  2.429139  85.540790   719.57190    25.4     2.0    81.0
# 1342  26.457268  2.405072  86.537570   718.16780    25.3     0.7    81.0
# 1343  26.337826  2.403560  87.253746   729.44604    25.4     2.4    78.0
#
#        True_3
# 0     1875.60
# 1     1746.00
# 2     1794.24
# 3     2265.48
# ...
